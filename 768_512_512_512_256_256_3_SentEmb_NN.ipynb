# %%
import pandas as pd
import numpy as np
# import required libraries for tree based models
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn import tree
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
droppedna_merged_df =  pd.read_csv('embedded_updated_label.csv')

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA

import matplotlib.pyplot as plt

from sklearn.utils.class_weight import compute_class_weight



# Split the data into training and validation sets
train_df, val_df = train_test_split(droppedna_merged_df, test_size=0.2, random_state=42)

# Extract features (embeddings) and labels
X_train = train_df.iloc[:, -769:-1]  # Assuming embeddings start from the third column
y_train = train_df['Type']

X_val = val_df.iloc[:, -769:-1]
y_val = val_df['Type']

# Calculate class weights based on the inverse of the number of members in each class
class_weights = compute_class_weight('balanced', classes = np.unique(y_train), y = y_train)
class_weights_tensor = torch.tensor(class_weights, dtype=torch.float32)

# %%
# Define a simple feedforward neural network with customizable hidden layers
class SimpleNN(nn.Module):
    def __init__(self, input_size, hidden_sizes, output_size):
        super(SimpleNN, self).__init__()

        layers = []
        in_size = input_size
        for hidden_size in hidden_sizes:
            layers.append(nn.Linear(in_size, hidden_size))
            layers.append(nn.ReLU())
            in_size = hidden_size

        layers.append(nn.Linear(in_size, output_size))
        self.network = nn.Sequential(*layers)

    def forward(self, x):
        return self.network(x)

# Initialize the model, loss function, and optimizer
input_size = X_train.shape[1]  # Assuming the input size is the number of features in the embeddings
hidden_sizes = [512, 512, 512, 256, 256]  # Customize hidden layer sizes
output_size = len(np.unique(y_train))
model = SimpleNN(input_size, hidden_sizes, output_size)
criterion = nn.CrossEntropyLoss(weight=class_weights_tensor)
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Convert data to PyTorch tensors
X_train_tensor = torch.tensor(X_train.values, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train.values, dtype=torch.long)

# Variables for early stopping
best_val_loss = np.inf
no_improvement_count = 0
early_stopping_threshold = 20  # Number of consecutive epochs without improvement to trigger early stopping
model_checkpoint_path = '768_512_512_512_256_256_3_SentEmb_NN.pth'  # Path to save the model checkpoint

# %%
# Training loop with early stopping
epochs = 1000
for epoch in range(epochs):
    # Forward pass
    outputs = model(X_train_tensor)
    loss = criterion(outputs, y_train_tensor)

    # Backward pass and optimization
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    # Calculate training accuracy
    _, predicted_train = torch.max(outputs, 1)
    train_accuracy = (predicted_train == y_train_tensor).sum().item() / len(y_train_tensor)

    # Validation loss and accuracy
    with torch.no_grad():
        model.eval()
        X_val_tensor = torch.tensor(X_val.values, dtype=torch.float32)
        y_val_tensor = torch.tensor(y_val.values, dtype=torch.long)
        val_outputs = model(X_val_tensor)
        val_loss = criterion(val_outputs, y_val_tensor)

        _, predicted_val = torch.max(val_outputs, 1)
        val_accuracy = (predicted_val == y_val_tensor).sum().item() / len(y_val_tensor)

    # Print loss and accuracy for monitoring training progress
    print(f'Epoch [{epoch+1}/{epochs}], Loss: {loss.item()}, Training Accuracy: {train_accuracy:.4f}, Validation Loss: {val_loss.item()}, Validation Accuracy: {val_accuracy:.4f}')

    # Check for early stopping
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        no_improvement_count = 0
        # Save the model checkpoint
        torch.save(model.state_dict(), model_checkpoint_path)
    else:
        no_improvement_count += 1

    # Check if early stopping criteria met
    if no_improvement_count >= early_stopping_threshold:
        print(f'Early stopping triggered after {epoch+1} epochs without improvement.')
        break
# Out:
# Epoch [1/1000], Loss: 1.0995628833770752, Training Accuracy: 0.0286, Validation Loss: 1.098246455192566, Validation Accuracy: 0.0279
# Epoch [2/1000], Loss: 1.0983126163482666, Training Accuracy: 0.0286, Validation Loss: 1.0969713926315308, Validation Accuracy: 0.9440
# Epoch [3/1000], Loss: 1.0969460010528564, Training Accuracy: 0.9442, Validation Loss: 1.0940450429916382, Validation Accuracy: 0.9452
# Epoch [4/1000], Loss: 1.0939387083053589, Training Accuracy: 0.9453, Validation Loss: 1.0879740715026855, Validation Accuracy: 0.8696
# Epoch [5/1000], Loss: 1.0876784324645996, Training Accuracy: 0.8677, Validation Loss: 1.0777024030685425, Validation Accuracy: 0.6009
# Epoch [6/1000], Loss: 1.0770527124404907, Training Accuracy: 0.6021, Validation Loss: 1.0626188516616821, Validation Accuracy: 0.3536
# Epoch [7/1000], Loss: 1.0614511966705322, Training Accuracy: 0.3590, Validation Loss: 1.041427731513977, Validation Accuracy: 0.2884
# Epoch [8/1000], Loss: 1.039685606956482, Training Accuracy: 0.2910, Validation Loss: 1.0112255811691284, Validation Accuracy: 0.2343
# Epoch [9/1000], Loss: 1.0086874961853027, Training Accuracy: 0.2361, Validation Loss: 0.970070481300354, Validation Accuracy: 0.1640
# Epoch [10/1000], Loss: 0.9659438133239746, Training Accuracy: 0.1652, Validation Loss: 0.9160956144332886, Validation Accuracy: 0.1471
# Epoch [11/1000], Loss: 0.909672737121582, Training Accuracy: 0.1480, Validation Loss: 0.8509464859962463, Validation Accuracy: 0.1685
# Epoch [12/1000], Loss: 0.8412219285964966, Training Accuracy: 0.1718, Validation Loss: 0.7800489068031311, Validation Accuracy: 0.2051
# Epoch [13/1000], Loss: 0.7653276920318604, Training Accuracy: 0.2080, Validation Loss: 0.6992984414100647, Validation Accuracy: 0.3594
# Epoch [14/1000], Loss: 0.6816195249557495, Training Accuracy: 0.3590, Validation Loss: 0.6219573616981506, Validation Accuracy: 0.5802
# Epoch [15/1000], Loss: 0.5992265939712524, Training Accuracy: 0.5829, Validation Loss: 0.6027067303657532, Validation Accuracy: 0.7768
# Epoch [16/1000], Loss: 0.5839992761611938, Training Accuracy: 0.7777, Validation Loss: 0.6754273176193237, Validation Accuracy: 0.5966
# Epoch [17/1000], Loss: 0.6366935968399048, Training Accuracy: 0.6001, Validation Loss: 0.5606722235679626, Validation Accuracy: 0.7215
# Epoch [18/1000], Loss: 0.5363622903823853, Training Accuracy: 0.7204, Validation Loss: 0.599388599395752, Validation Accuracy: 0.6361
# Epoch [19/1000], Loss: 0.5764333009719849, Training Accuracy: 0.6355, Validation Loss: 0.5859678387641907, Validation Accuracy: 0.5204
# Epoch [20/1000], Loss: 0.5452868342399597, Training Accuracy: 0.5241, Validation Loss: 0.5577284693717957, Validation Accuracy: 0.6189
# Epoch [21/1000], Loss: 0.5190588235855103, Training Accuracy: 0.6214, Validation Loss: 0.5320864915847778, Validation Accuracy: 0.8330
# Epoch [22/1000], Loss: 0.5074897408485413, Training Accuracy: 0.8329, Validation Loss: 0.5353001356124878, Validation Accuracy: 0.8462
# Epoch [23/1000], Loss: 0.5123052597045898, Training Accuracy: 0.8472, Validation Loss: 0.49155452847480774, Validation Accuracy: 0.7533
# Epoch [24/1000], Loss: 0.4602228105068207, Training Accuracy: 0.7535, Validation Loss: 0.514355480670929, Validation Accuracy: 0.6225
# Epoch [25/1000], Loss: 0.4784502685070038, Training Accuracy: 0.6232, Validation Loss: 0.4719253182411194, Validation Accuracy: 0.6749
# Epoch [26/1000], Loss: 0.4427116811275482, Training Accuracy: 0.6749, Validation Loss: 0.4849611520767212, Validation Accuracy: 0.7094
# Epoch [27/1000], Loss: 0.4612390398979187, Training Accuracy: 0.7089, Validation Loss: 0.45324403047561646, Validation Accuracy: 0.7420
# Epoch [28/1000], Loss: 0.42672625184059143, Training Accuracy: 0.7419, Validation Loss: 0.45695045590400696, Validation Accuracy: 0.7225
# Epoch [29/1000], Loss: 0.4244285523891449, Training Accuracy: 0.7236, Validation Loss: 0.45504623651504517, Validation Accuracy: 0.7637
# Epoch [30/1000], Loss: 0.42183318734169006, Training Accuracy: 0.7626, Validation Loss: 0.43591374158859253, Validation Accuracy: 0.8364
# Epoch [31/1000], Loss: 0.40555527806282043, Training Accuracy: 0.8358, Validation Loss: 0.4381495714187622, Validation Accuracy: 0.8412
# Epoch [32/1000], Loss: 0.40882349014282227, Training Accuracy: 0.8393, Validation Loss: 0.41601452231407166, Validation Accuracy: 0.8047
# Epoch [33/1000], Loss: 0.3842620551586151, Training Accuracy: 0.8032, Validation Loss: 0.421656996011734, Validation Accuracy: 0.7344
# Epoch [34/1000], Loss: 0.3864173889160156, Training Accuracy: 0.7320, Validation Loss: 0.41094669699668884, Validation Accuracy: 0.7364
# Epoch [35/1000], Loss: 0.37575656175613403, Training Accuracy: 0.7348, Validation Loss: 0.3989788591861725, Validation Accuracy: 0.7849
# Epoch [36/1000], Loss: 0.36562228202819824, Training Accuracy: 0.7826, Validation Loss: 0.3942561149597168, Validation Accuracy: 0.8085
# Epoch [37/1000], Loss: 0.35990163683891296, Training Accuracy: 0.8075, Validation Loss: 0.38149264454841614, Validation Accuracy: 0.8113
# Epoch [38/1000], Loss: 0.3432011306285858, Training Accuracy: 0.8110, Validation Loss: 0.386491984128952, Validation Accuracy: 0.8071
# Epoch [39/1000], Loss: 0.34474092721939087, Training Accuracy: 0.8060, Validation Loss: 0.37146130204200745, Validation Accuracy: 0.8403
# Epoch [40/1000], Loss: 0.3296317160129547, Training Accuracy: 0.8390, Validation Loss: 0.36797624826431274, Validation Accuracy: 0.8530
# Epoch [41/1000], Loss: 0.32688671350479126, Training Accuracy: 0.8524, Validation Loss: 0.3559747636318207, Validation Accuracy: 0.8346
# Epoch [42/1000], Loss: 0.3138236701488495, Training Accuracy: 0.8342, Validation Loss: 0.35525456070899963, Validation Accuracy: 0.8013
# Epoch [43/1000], Loss: 0.31119751930236816, Training Accuracy: 0.8009, Validation Loss: 0.3465747833251953, Validation Accuracy: 0.8094
# Epoch [44/1000], Loss: 0.30229562520980835, Training Accuracy: 0.8092, Validation Loss: 0.3409939110279083, Validation Accuracy: 0.8394
# Epoch [45/1000], Loss: 0.29636523127555847, Training Accuracy: 0.8387, Validation Loss: 0.33478567004203796, Validation Accuracy: 0.8506
# Epoch [46/1000], Loss: 0.28778547048568726, Training Accuracy: 0.8505, Validation Loss: 0.33285602927207947, Validation Accuracy: 0.8423
# Epoch [47/1000], Loss: 0.2825562357902527, Training Accuracy: 0.8423, Validation Loss: 0.3277975916862488, Validation Accuracy: 0.8527
# Epoch [48/1000], Loss: 0.27580973505973816, Training Accuracy: 0.8516, Validation Loss: 0.32249024510383606, Validation Accuracy: 0.8698
# Epoch [49/1000], Loss: 0.27011218667030334, Training Accuracy: 0.8689, Validation Loss: 0.31493955850601196, Validation Accuracy: 0.8611
# Epoch [50/1000], Loss: 0.2622951865196228, Training Accuracy: 0.8599, Validation Loss: 0.3112224340438843, Validation Accuracy: 0.8376
# Epoch [51/1000], Loss: 0.2586277723312378, Training Accuracy: 0.8367, Validation Loss: 0.3044385313987732, Validation Accuracy: 0.8467
# Epoch [52/1000], Loss: 0.25115296244621277, Training Accuracy: 0.8456, Validation Loss: 0.3027961850166321, Validation Accuracy: 0.8633
# Epoch [53/1000], Loss: 0.24753186106681824, Training Accuracy: 0.8634, Validation Loss: 0.2967153489589691, Validation Accuracy: 0.8633
# Epoch [54/1000], Loss: 0.23939694464206696, Training Accuracy: 0.8631, Validation Loss: 0.2956711947917938, Validation Accuracy: 0.8596
# Epoch [55/1000], Loss: 0.23631253838539124, Training Accuracy: 0.8604, Validation Loss: 0.2916018068790436, Validation Accuracy: 0.8783
# Epoch [56/1000], Loss: 0.22963109612464905, Training Accuracy: 0.8793, Validation Loss: 0.28772568702697754, Validation Accuracy: 0.8802
# Epoch [57/1000], Loss: 0.22469066083431244, Training Accuracy: 0.8812, Validation Loss: 0.2815083861351013, Validation Accuracy: 0.8639
# Epoch [58/1000], Loss: 0.2194995880126953, Training Accuracy: 0.8650, Validation Loss: 0.2769182026386261, Validation Accuracy: 0.8672
# Epoch [59/1000], Loss: 0.2138911336660385, Training Accuracy: 0.8683, Validation Loss: 0.2763688862323761, Validation Accuracy: 0.8791
# Epoch [60/1000], Loss: 0.2099764198064804, Training Accuracy: 0.8810, Validation Loss: 0.2711280286312103, Validation Accuracy: 0.8756
# Epoch [61/1000], Loss: 0.2035790979862213, Training Accuracy: 0.8775, Validation Loss: 0.26920413970947266, Validation Accuracy: 0.8758
# Epoch [62/1000], Loss: 0.19949641823768616, Training Accuracy: 0.8783, Validation Loss: 0.269618421792984, Validation Accuracy: 0.8913
# Epoch [63/1000], Loss: 0.1947837769985199, Training Accuracy: 0.8939, Validation Loss: 0.2642848789691925, Validation Accuracy: 0.8865
# Epoch [64/1000], Loss: 0.18905898928642273, Training Accuracy: 0.8899, Validation Loss: 0.2593461871147156, Validation Accuracy: 0.8791
# Epoch [65/1000], Loss: 0.18508930504322052, Training Accuracy: 0.8821, Validation Loss: 0.25906693935394287, Validation Accuracy: 0.8908
# Epoch [66/1000], Loss: 0.18025971949100494, Training Accuracy: 0.8935, Validation Loss: 0.2545742392539978, Validation Accuracy: 0.8884
# Epoch [67/1000], Loss: 0.1750239133834839, Training Accuracy: 0.8917, Validation Loss: 0.25176823139190674, Validation Accuracy: 0.8875
# Epoch [68/1000], Loss: 0.17082162201404572, Training Accuracy: 0.8914, Validation Loss: 0.25612571835517883, Validation Accuracy: 0.9037
# Epoch [69/1000], Loss: 0.16657370328903198, Training Accuracy: 0.9066, Validation Loss: 0.24924345314502716, Validation Accuracy: 0.8969
# Epoch [70/1000], Loss: 0.16160880029201508, Training Accuracy: 0.8999, Validation Loss: 0.24913352727890015, Validation Accuracy: 0.9025
# Epoch [71/1000], Loss: 0.15664595365524292, Training Accuracy: 0.9056, Validation Loss: 0.24795286357402802, Validation Accuracy: 0.9042
# Epoch [72/1000], Loss: 0.15232688188552856, Training Accuracy: 0.9076, Validation Loss: 0.24234671890735626, Validation Accuracy: 0.8988
# Epoch [73/1000], Loss: 0.14851020276546478, Training Accuracy: 0.9022, Validation Loss: 0.25350797176361084, Validation Accuracy: 0.9137
# Epoch [74/1000], Loss: 0.1450858861207962, Training Accuracy: 0.9173, Validation Loss: 0.24075600504875183, Validation Accuracy: 0.8977
# Epoch [75/1000], Loss: 0.14276744425296783, Training Accuracy: 0.9018, Validation Loss: 0.2679472863674164, Validation Accuracy: 0.9247
# Epoch [76/1000], Loss: 0.14134688675403595, Training Accuracy: 0.9279, Validation Loss: 0.24019700288772583, Validation Accuracy: 0.8930
# Epoch [77/1000], Loss: 0.14054255187511444, Training Accuracy: 0.8972, Validation Loss: 0.2700751721858978, Validation Accuracy: 0.9268
# Epoch [78/1000], Loss: 0.13381655514240265, Training Accuracy: 0.9296, Validation Loss: 0.2422657012939453, Validation Accuracy: 0.9091
# Epoch [79/1000], Loss: 0.12573832273483276, Training Accuracy: 0.9142, Validation Loss: 0.24808210134506226, Validation Accuracy: 0.9162
# Epoch [80/1000], Loss: 0.12069408595561981, Training Accuracy: 0.9210, Validation Loss: 0.2725020945072174, Validation Accuracy: 0.9308
# Epoch [81/1000], Loss: 0.12052392214536667, Training Accuracy: 0.9349, Validation Loss: 0.24436046183109283, Validation Accuracy: 0.9054
# Epoch [82/1000], Loss: 0.12195539474487305, Training Accuracy: 0.9107, Validation Loss: 0.28781136870384216, Validation Accuracy: 0.9368
# Epoch [83/1000], Loss: 0.11702843755483627, Training Accuracy: 0.9406, Validation Loss: 0.24795368313789368, Validation Accuracy: 0.9153
# Epoch [84/1000], Loss: 0.11043278127908707, Training Accuracy: 0.9212, Validation Loss: 0.26483190059661865, Validation Accuracy: 0.9288
# Epoch [85/1000], Loss: 0.10374793410301208, Training Accuracy: 0.9342, Validation Loss: 0.2830796241760254, Validation Accuracy: 0.9366
# Epoch [86/1000], Loss: 0.10278543084859848, Training Accuracy: 0.9410, Validation Loss: 0.25136154890060425, Validation Accuracy: 0.9167
# Epoch [87/1000], Loss: 0.10486293584108353, Training Accuracy: 0.9227, Validation Loss: 0.30528736114501953, Validation Accuracy: 0.9440
# Epoch [88/1000], Loss: 0.09991344809532166, Training Accuracy: 0.9480, Validation Loss: 0.2626590132713318, Validation Accuracy: 0.9282
# Epoch [89/1000], Loss: 0.0945311039686203, Training Accuracy: 0.9337, Validation Loss: 0.2854538559913635, Validation Accuracy: 0.9401
# Epoch [90/1000], Loss: 0.08874324709177017, Training Accuracy: 0.9449, Validation Loss: 0.30298030376434326, Validation Accuracy: 0.9451
# Epoch [91/1000], Loss: 0.0873539075255394, Training Accuracy: 0.9493, Validation Loss: 0.26667454838752747, Validation Accuracy: 0.9295
# Epoch [92/1000], Loss: 0.08876809477806091, Training Accuracy: 0.9352, Validation Loss: 0.3298274576663971, Validation Accuracy: 0.9496
# Epoch [93/1000], Loss: 0.08517935127019882, Training Accuracy: 0.9543, Validation Loss: 0.2748335599899292, Validation Accuracy: 0.9341
# Epoch [94/1000], Loss: 0.08280704915523529, Training Accuracy: 0.9403, Validation Loss: 0.32273900508880615, Validation Accuracy: 0.9499
# Epoch [95/1000], Loss: 0.07631862908601761, Training Accuracy: 0.9545, Validation Loss: 0.31612783670425415, Validation Accuracy: 0.9487
# Epoch [96/1000], Loss: 0.07280413806438446, Training Accuracy: 0.9543, Validation Loss: 0.302020788192749, Validation Accuracy: 0.9455
# Early stopping triggered after 96 epochs without improvement.

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Load the best model checkpoint
model.load_state_dict(torch.load(model_checkpoint_path))

# Make predictions on the validation set
with torch.no_grad():
    model.eval()
    val_outputs = model(torch.tensor(X_val.values, dtype=torch.float32))
    _, predicted_labels = torch.max(val_outputs, 1)

# Convert predicted labels to numpy array
predicted_labels_np = predicted_labels.numpy()

# Compute the confusion matrix
conf_matrix = confusion_matrix(y_val, predicted_labels_np)

# Display the confusion matrix using seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=np.unique(y_val), yticklabels=np.unique(y_val))
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %%
from sklearn.metrics import confusion_matrix, precision_recall_fscore_support
import seaborn as sns
import matplotlib.pyplot as plt

# Load the best model checkpoint
model.load_state_dict(torch.load(model_checkpoint_path))

# Make predictions on the validation set
with torch.no_grad():
    model.eval()
    val_outputs = model(torch.tensor(X_val.values, dtype=torch.float32))
    _, predicted_labels = torch.max(val_outputs, 1)

# Convert predicted labels to numpy array
predicted_labels_np = predicted_labels.numpy()

# Compute the confusion matrix
conf_matrix = confusion_matrix(y_val, predicted_labels_np)

# Display the confusion matrix using seaborn
plt.figure(figsize=(12, 8))

# Plot Confusion Matrix
plt.subplot(2, 2, 1)
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['0','1','2'], yticklabels=['0','1','2'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')

# Calculate macro and micro average metrics
precision, recall, f1, _ = precision_recall_fscore_support(y_val, predicted_labels_np, average='macro')
print(f"Macro Precision: {precision:.4f}, Recall: {recall:.4f}, F1-score: {f1:.4f}")

precision_micro, recall_micro, f1_micro, _ = precision_recall_fscore_support(y_val, predicted_labels_np, average='micro')
print(f"Micro Precision: {precision_micro:.4f}, Recall: {recall_micro:.4f}, F1-score: {f1_micro:.4f}")

# Display the classification report
class_report = classification_report(y_val, predicted_labels_np, target_names=['0','1','2'])
print("Classification Report:\n", class_report)

# Plot Normalized Confusion Matrix
plt.subplot(2, 2, 2)
sns.heatmap(conf_matrix/np.sum(conf_matrix), annot=True, fmt='.2%', cmap='Blues', xticklabels=['0','1','2'], yticklabels=['0','1','2'])
plt.title('Normalized Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')

plt.show()
# Out:
# Macro Precision: 0.6448, Recall: 0.9078, F1-score: 0.6665
# Micro Precision: 0.8930, Recall: 0.8930, F1-score: 0.8930
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.89      0.94     31577
#            1       0.85      0.96      0.90       915
#            2       0.09      0.88      0.16       357
#
#     accuracy                           0.89     32849
#    macro avg       0.64      0.91      0.67     32849
# weighted avg       0.98      0.89      0.93     32849

# %%
# Perform PCA on the last hidden layer output

# Load the best model checkpoint
model.load_state_dict(torch.load(model_checkpoint_path))


# Apply PCA on internal representations of the neural network
with torch.no_grad():
    model.eval()
    X_train_tensor = torch.tensor(X_train.values, dtype=torch.float32)
    internal_representation = model.network[:-1](X_train_tensor).numpy()  # Exclude the last layer for visualization

# Apply PCA for dimensionality reduction
n_components = 2
pca = PCA(n_components=n_components)
reduced_representation = pca.fit_transform(internal_representation)

# %%
# Combine reduced representation and labels into a single array
data = np.column_stack((reduced_representation, y_train))

# Sort the data based on class labels
sorted_data = data[data[:, 2].argsort()]

# Your existing code for scatter plot
scatter_plot = plt.scatter(sorted_data[:, 0], sorted_data[:, 1], c=sorted_data[:, 2], cmap='viridis')
plt.title('Learned Representation (2D)')
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')

# Adding color legend
plt.colorbar(scatter_plot, label='Class Label')

# Display the plot
plt.show()
