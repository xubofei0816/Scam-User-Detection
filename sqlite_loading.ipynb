# %%
import pandas as pd
import sqlite3

con = sqlite3.connect("data.sqlite")
'''
# Load the data into a DataFrame
surveys_df = pd.read_sql_query("SELECT * from surveys", con)

# Select only data for 2002
surveys2002 = surveys_df[surveys_df.year == 2002]

# Write the new DataFrame to a new SQLite table
surveys2002.to_sql("surveys2002", con, if_exists="replace")

con.close()
'''
# Out:
# '\n# Load the data into a DataFrame\nsurveys_df = pd.read_sql_query("SELECT * from surveys", con)\n\n# Select only data for 2002\nsurveys2002 = surveys_df[surveys_df.year == 2002]\n\n# Write the new DataFrame to a new SQLite table\nsurveys2002.to_sql("surveys2002", con, if_exists="replace")\n\ncon.close()\n'

# %%
# Connect to the SQLite database
db_path = 'data.sqlite'  # Replace with the actual path to your SQLite database
connection = sqlite3.connect(db_path)

# Create a cursor object to execute SQL queries
cursor = connection.cursor()

# Get the list of tables in the database
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()

# Iterate through tables and print column information
for table in tables:
    table_name = table[0]
    print(f"Table: {table_name}")

    # Get column information for each table
    cursor.execute(f"PRAGMA table_info({table_name});")
    columns = cursor.fetchall()

    # Print column information
    for column in columns:
        print(f"  Column: {column[1]}, Type: {column[2]}, Nullable: {'YES' if column[3] else 'NO'}")

# Close the cursor and connection
cursor.close()
connection.close()
# Out:
# Table: Data
#   Column: ID, Type: , Nullable: NO
#   Column: User_id, Type: , Nullable: NO
#   Column: Sold, Type: , Nullable: NO
#   Column: Gender, Type: , Nullable: NO
#   Column: Category, Type: , Nullable: NO
#   Column: subcategory, Type: , Nullable: NO
#   Column: size, Type: , Nullable: NO
#   Column: State, Type: , Nullable: NO
#   Column: Brand, Type: , Nullable: NO
#   Column: Colors, Type: , Nullable: NO
#   Column: Price, Type: , Nullable: NO
#   Column: Image, Type: , Nullable: NO
#   Column: Images, Type: , Nullable: NO
#   Column: Description, Type: , Nullable: NO
#   Column: Title, Type: , Nullable: NO
#   Column: Platform, Type: , Nullable: NO
# Table: Depop_Data
#   Column: ID, Type: , Nullable: NO
#   Column: User_id, Type: , Nullable: NO
#   Column: Sold, Type: , Nullable: NO
#   Column: Gender, Type: , Nullable: NO
#   Column: Category, Type: , Nullable: NO
#   Column: subcategory, Type: , Nullable: NO
#   Column: size, Type: , Nullable: NO
# ...

# %%
users_df = pd.read_sql_query("SELECT * from Users ", con)
users_df.head()
# Out:
#    Username   User_id Gender  Given_item_count  Taken_item_count  \
# 0  gucci.07  13371337      F                 0                57
#
#    Followers_count  Following_count  Positive_feedback_count  \
# 0                5               13                       15
#
#    Negative_feedback_count  Feedback_reputation  ... Created_at  \
# 0                        2                  0.9  ...
#
#             Last_loged_on_ts City_id            City Country_title  \
# 0  2023-08-31T12:49:27+02:00   14844  Mons-en-Barœul        France
#
#   Verification_email  Verification_facebook  Verification_google  \
# 0                  1                      0                    1
#
#    Verification_phone  Platform
# 0                   0      None
#
# [1 rows x 21 columns]

# %%
depop_users_df = pd.read_sql_query("SELECT * from Depop_Data ", con)
depop_users_df.head()
# Out:
#           ID   User_id Sold Gender       Category subcategory size      State  \
# 0  376077480  43283981    M   male  coats-jackets     jackets       Brand new
# 1  376077148  43283981    S   male  coats-jackets      gilets   XL  Brand new
# 2  376076821  43283981    P   male  coats-jackets     jackets       Brand new
# 3  376076726  43283981    P   male  coats-jackets     jackets       Brand new
# 4  376076578  43283981    P   male  coats-jackets     jackets       Brand new
#
#             Brand Colors      Price Image  \
# 0  the-north-face         200.00USD  None
# 1  the-north-face  Black  160.00USD  None
# 2  the-north-face         230.00USD  None
# 3  the-north-face  Black  240.00USD  None
# 4  the-north-face  Black  230.00USD  None
#
#                                          Description  \
# 0  🛩️ Ships same day \n🤝 NWT guaranteed \nThe Nor...
# 1  🛩️ Ships same day \n🤝 NWT guaranteed \nThe Nor...
# 2  🛩️ Ships same day \n🤝 NWT guaranteed \nThe Nor...
# ...

# %%
users_df.columns
# Out:
# Index(['Username', 'User_id', 'Gender', 'Given_item_count', 'Taken_item_count',
#        'Followers_count', 'Following_count', 'Positive_feedback_count',
#        'Negative_feedback_count', 'Feedback_reputation', 'Avatar',
#        'Created_at', 'Last_loged_on_ts', 'City_id', 'City', 'Country_title',
#        'Verification_email', 'Verification_facebook', 'Verification_google',
#        'Verification_phone', 'Platform'],
#       dtype='object')
